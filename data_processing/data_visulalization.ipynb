# %%
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
input_data_12= np.loadtxt('/home/linux/Documents/texture_haptic/raw_data/test11.txt', delimiter = ',')

# %%
input_data_12
# Out:
# array([[-7.43052622e+08, -7.43052621e+08,  1.50000000e+01,
#          7.00000000e+00],
#        [-7.43052586e+08, -7.43052586e+08,  1.70000000e+01,
#          7.00000000e+00],
#        [-7.43052560e+08, -7.43052560e+08,  1.80000000e+01,
#          8.00000000e+00],
#        ...,
#        [-7.36277749e+08, -7.36277749e+08, -1.20390000e+04,
#         -1.24970000e+04],
#        [-7.36277729e+08, -7.36277729e+08, -1.20380000e+04,
#         -1.24980000e+04],
#        [-7.36277713e+08, -7.36277712e+08, -1.20370000e+04,
#         -1.24980000e+04]])

# %%
# Data for plotting
plt.figure(figsize=(10, 10))

#plt.plot(input_data_matrix_118_3[:,0], input_data_matrix_118_3[:,3]*0.005, c = 'r', label='input_data_matrix_118_3')
#plt.plot(input_data_matrix_111_1[:,0], input_data_matrix_111_1[:,3]*0.005, c = 'k', label='input_data_matrix_111_1')

plt.plot(input_data_12[:,0], input_data_12[:,2]*0.001, c = 'k', label='input_data_10')
plt.plot(input_data_12[:,0], input_data_12[:,3]*0.005, c = 'r', label='input_data_10')

plt.xlabel('Time (s)')
plt.ylabel('Position (mm)')
plt.title('Position vs time')

#plt.plot(features_matrix_3[:,0], features_matrix_3[:,3]*0.005)
#plt.set(xlabel='Force', ylabel='Deformation', title='deformation ratio')
plt.legend()
plt.grid()
plt.show()
