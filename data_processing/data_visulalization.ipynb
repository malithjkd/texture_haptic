# %%
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
input_data_14= np.loadtxt('/home/linux/Documents/texture_haptic/raw_data/s1_f100_i001.txt', delimiter = ',')
input_data_15= np.loadtxt('/home/linux/Documents/texture_haptic/raw_data/s1_f100_i002.txt', delimiter = ',')

# %%
input_data_14
# Out:
# array([[1.580000e-04, 0.000000e+00, 0.000000e+00],
#        [2.620000e-04, 0.000000e+00, 0.000000e+00],
#        [3.510000e-04, 0.000000e+00, 0.000000e+00],
#        ...,
#        [7.636720e+00, 8.080500e+04, 2.800000e+02],
#        [7.636738e+00, 8.080600e+04, 2.800000e+02],
#        [7.636757e+00, 8.080600e+04, 2.800000e+02]])

# %%
# Data for plotting
plt.figure(figsize=(10, 10))

#plt.plot(input_data_matrix_118_3[:,0], input_data_matrix_118_3[:,3]*0.005, c = 'r', label='input_data_matrix_118_3')
#plt.plot(input_data_matrix_111_1[:,0], input_data_matrix_111_1[:,3]*0.005, c = 'k', label='input_data_matrix_111_1')

#plt.plot(input_data_14[:,0], input_data_14[:,1]*0.001, c = 'k', label='input_data_10')
plt.plot(input_data_14[:,0], input_data_14[:,2]*0.005, c = 'r', label='input_data_10')
plt.plot(input_data_15[:,0], input_data_15[:,2]*0.005, c = 'b', label='input_data_10')

plt.xlabel('Time (s)')
plt.ylabel('Position (mm)')
plt.title('Position vs time')

#plt.plot(features_matrix_3[:,0], features_matrix_3[:,3]*0.005)
#plt.set(xlabel='Force', ylabel='Deformation', title='deformation ratio')
plt.legend()
plt.grid()
plt.show()
