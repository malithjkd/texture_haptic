# %%
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
input_data_12= np.loadtxt('/home/linux/Documents/texture_haptic/raw_data/test11.txt', delimiter = ',')

# %%
input_data_12
# Out:
# array([[-1.09134788e+09, -1.09134788e+09,  1.80000000e+01,
#          0.00000000e+00],
#        [-1.09134785e+09, -1.09134785e+09,  2.00000000e+01,
#          0.00000000e+00],
#        [-1.09134784e+09, -1.09134784e+09,  2.10000000e+01,
#          0.00000000e+00],
#        ...,
#        [-1.08458110e+09, -1.08458110e+09,  1.74820000e+04,
#          0.00000000e+00],
#        [-1.08458108e+09, -1.08458108e+09,  1.74830000e+04,
#          0.00000000e+00],
#        [-1.08458106e+09, -1.08458106e+09,  1.74830000e+04,
#          0.00000000e+00]])

# %%
# Data for plotting
plt.figure(figsize=(10, 10))

#plt.plot(input_data_matrix_118_3[:,0], input_data_matrix_118_3[:,3]*0.005, c = 'r', label='input_data_matrix_118_3')
#plt.plot(input_data_matrix_111_1[:,0], input_data_matrix_111_1[:,3]*0.005, c = 'k', label='input_data_matrix_111_1')

plt.plot(input_data_12[:,0], input_data_12[:,2]*0.001, c = 'k', label='input_data_10')
plt.plot(input_data_12[:,0], input_data_12[:,3]*0.005, c = 'k', label='input_data_10')

plt.xlabel('Time (s)')
plt.ylabel('Position (mm)')
plt.title('Position vs time')

#plt.plot(features_matrix_3[:,0], features_matrix_3[:,3]*0.005)
#plt.set(xlabel='Force', ylabel='Deformation', title='deformation ratio')
plt.legend()
plt.grid()
plt.show()
